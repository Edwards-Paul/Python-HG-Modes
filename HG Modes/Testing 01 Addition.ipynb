# %%
import PauLisa as pl
# Out:
# DEFAULT PARAMS (PauLisa.defaultParams)
#  wavelength =1.064e-06m
#  waist size(w0) =0.001m
#  z0 =0m
#  Rayleigh Range (Zr) =2.95262467443m
#
#
# DEFAULT X,Y PLANE (PauLisa.defaultPlane)
#  x: -0.02m to 0.02m with 1000 points.
#  y: -0.02m to 0.02m with 1000 points.
#
#
#
# Function Usage:
# OPTICAL PARAMETERS DEFINITION
#  PARAMETERS=PauLisa.Params(wavelength,w0,z0)
#
# PLANE OF PROPAGATION DEFINITION
#  PLANE=PauLisa.Plane(xmin,xmax,xpoints,ymin,ymax,ypoints)
#
# MODES DEFNITION AND DISPLAY
#  MODESARRAY=PauLisa.Modes((n1,m1,c1),(n2,m2,c2))
#  PauLisa.ShowModes(MODES)
#
# AMPLITUDE CALCULATIONS
#  Calculate amplitude over plane: RESULT=PauLisa.Calculate(PARAMS,PLANE,MODES,z)
#  Simple calculation from coordinates: PauLisa.Amplitude(PARAMS,x,y,z,MODES)
#
# INTENSITY PLOTTING
#  PauLisa.Contour(RESULT, **xlim,**ylim)
#  PauLisa.IntensitySliceX(y, *RESULT, **xlim)
#  PauLisa.IntensitySliceY(x, *RESULT, **xlim)
#
# PHASE CALCULATION
#  PauLisa.Phase(PARAMS,x,y,z,MODES)
#
# PHASE PLOTTING
#  PauLisa.PhaseContour(RESULT,**xlim,**ylim)
#  PauLisa.PhaseSliceX(y,*RESULT,**xlim)
#  PauLisa.PhaseSliceY(x,*RESULT,**xlim)
#
#  *VARNAME represents variable number of args of specified type.

# %%
a=pl.defaultParams
b=pl.Plane(-1e-3,1e-3,40000,-1e-3,1e-3,3)

# %% [markdown]
# #  1mm beam waist, at waist, add HG10 mode in phase

# %% [markdown]
# ## Calculate2 (q parameter)

# %%
# Re[a10]/a00 = delta s/wo , w0 = 1e-3

a10 = .04
a00 = 1



m0 = pl.Modes((0,0,a00))
m1 = pl.Modes((1,0,a10))
m01 = pl.Modes((0,0,a00),(1,0,a10))

f0 =pl.Calculate2(a,b,m0,0)
f1 =pl.Calculate2(a,b,m1,0)
f01 = pl.Calculate2(a,b,m01,0)
f = pl.Calculate2(a,b,m01,0)


pl.IntensitySliceX2(0,f0,f1,f01)

print ("predicted x shift: "+str(pl.np.real(a10)/1*a.w0))
print ("actual: " + str(pl.peakInt(f01).x[0]-pl.peakInt(f0).x[0]))

print ("% err: " + str(((pl.np.real(a10)/1*a.w0)-(pl.peakInt(f01).x[0]-pl.peakInt(f0).x[0]))*100/(pl.np.real(a10)/1*a.w0)))
# Out:
# predicted x shift: 4e-05
# actual: 3.984999999999991e-05
# % err: 0.3750000000002293

# %%
# Re[a10]/a00 = delta s/wo , w0 = 1e-3

a10 = .08
a00 = 1

m0 = pl.Modes((0,0,a00))
m1 = pl.Modes((1,0,a10))
m01 = pl.Modes((0,0,a00),(1,0,a10))

f0 =pl.Calculate2(a,b,m0,0)
f1 =pl.Calculate2(a,b,m1,0)
f01 = pl.Calculate2(a,b,m01,0)

pl.IntensitySliceX2(0,f0,f1,f01)

print ("predicted x shift: "+str(pl.np.real(a10)/1*a.w0))
print ("actual: " + str(pl.peakInt(f01).x[0]-pl.peakInt(f0).x[0]))

print ("% err: " + str(((pl.np.real(a10)/1*a.w0)-(pl.peakInt(f01).x[0]-pl.peakInt(f0).x[0]))*100/(pl.np.real(a10)/1*a.w0)))
# Out:
# predicted x shift: 8e-05
# actual: 7.899999999999986e-05
# % err: 1.2500000000001827

# %% [markdown]
# ## Calculate(1) showing greater error

# %%
# Re[a10]/a00 = delta s/wo , w0 = 1e-3

a10 = .04
a00 = 1

m0 = pl.Modes((0,0,a00))
m1 = pl.Modes((1,0,a10))
m01 = pl.Modes((0,0,a00),(1,0,a10))

f0 =pl.Calculate(a,b,m0,0)
f1 =pl.Calculate(a,b,m1,0)
f01 = pl.Calculate(a,b,m01,0)

pl.IntensitySliceX(0,f0,f1,f01)

print ("predicted x shift: "+str(pl.np.real(a10)/1*a.w0))
print ("actual: " + str(pl.peakInt(f01).x[0]-pl.peakInt(f0).x[0]))

print ("% err: " + str(((pl.np.real(a10)/1*a.w0)-(pl.peakInt(f01).x[0]-pl.peakInt(f0).x[0]))*100/(pl.np.real(a10)/1*a.w0)))

print pl.Amplitude(a,2.82e-05,0,0,m01)
print pl.Amplitude(a,2.83e-05,0,0,m01)
# Out:
# predicted x shift: 4e-05
# actual: 3.984999999999991e-05
# % err: 0.3750000000002293
# (799.048899996+0j)
# (799.050763349+0j)

# %%
# Re[a10]/a00 = delta s/wo , w0 = 1e-3

a10 = .08
a00 = 1

m0 = pl.Modes((0,0,a00))
m1 = pl.Modes((1,0,a10))
m01 = pl.Modes((0,0,a00),(1,0,a10))

f0 =pl.Calculate(a,b,m0,0)
f1 =pl.Calculate(a,b,m1,0)
f01 = pl.Calculate(a,b,m01,0)

pl.IntensitySliceX(0,f0,f1,f01)

print ("predicted x shift: "+str(pl.np.real(a10)/a00*a.w0))
print ("actual: " + str(pl.peakInt(f01).x[0]-pl.peakInt(f0).x[0]))

print ("% err: " + str(((pl.np.real(a10)/1*a.w0)-(pl.peakInt(f01).x[0]-pl.peakInt(f0).x[0]))*100/(pl.np.real(a10)/1*a.w0)))
# Out:
# predicted x shift: 8e-05
# actual: 7.899999999999986e-05
# % err: 1.2500000000001827

# %%
# Re[a10]/a00 = delta s/wo , w0 = 1e-3

a10 = .16
a00 = 1

m0 = pl.Modes((0,0,a00))
m1 = pl.Modes((1,0,a10))
m01 = pl.Modes((0,0,a00),(1,0,a10))

f0 =pl.Calculate(a,b,m0,0)
f1 =pl.Calculate(a,b,m1,0)
f01 = pl.Calculate(a,b,m01,0)

pl.IntensitySliceX(0,f0,f1,f01)

print ("predicted x shift: "+str(pl.np.real(a10)/a00*a.w0))
print ("actual: " + str(pl.peakInt(f01).x[0]-pl.peakInt(f0).x[0]))

print ("% err: " + str(((pl.np.real(a10)/1*a.w0)-(pl.peakInt(f01).x[0]-pl.peakInt(f0).x[0]))*100/(pl.np.real(a10)/1*a.w0)))
# Out:
# predicted x shift: 0.00016
# actual: 0.00015255
# % err: 4.6562500000000115

# %% [markdown]
# # 1mm beam waist, at waist, add HG10 mode in quadrature phase

# %%
# Re[a10]/a00 = delta s/wo , w0 = 1e-3

a10 = .08*1j
a00 = 1

m0 = pl.Modes((0,0,a00))
m1 = pl.Modes((1,0,a10))
m = pl.Modes((1,0,1))
m01 = pl.Modes((0,0,a00),(1,0,a10))

f0 =pl.Calculate2(a,b,m0,0)
f1 =pl.Calculate2(a,b,m1,0)
f01 = pl.Calculate2(a,b,m01,0)
fa = pl.Calculate2(a,b,m,0)

pl.IntensitySliceX2(0,f0,f1,f01)
pl.PhaseSliceX2(0,f0,f1,f01)

# %%
# Re[a10]/a00 = delta s/wo , w0 = 1e-3

a10 = .08*1j
a00 = 1

m0 = pl.Modes((0,0,a00))
m1 = pl.Modes((1,0,a10))
m = pl.Modes((1,0,1))
m01 = pl.Modes((0,0,a00),(1,0,a10))

f0 =pl.Calculate(a,b,m0,0)
f1 =pl.Calculate(a,b,m1,0)
f01 = pl.Calculate(a,b,m01,0)
fa = pl.Calculate(a,b,m,0)

pl.IntensitySliceX(0,f0,f1,f01)
pl.PhaseSliceX(0,f0,f1,f01)

# %% [markdown]
# # 1mm beam waist, 1m from waist, add HG10 mode in quadrature phase

# %%
# Re[a10]/a00 = delta s/wo , w0 = 1e-3

a10 = .08*1j
a00 = 1

m0 = pl.Modes((0,0,a00))
m1 = pl.Modes((1,0,a10))
m = pl.Modes((1,0,1))
m01 = pl.Modes((0,0,a00),(1,0,a10))

f0 =pl.Calculate2(a,b,m0,1)
f1 =pl.Calculate2(a,b,m1,1)
f01 = pl.Calculate2(a,b,m01,1)
fa = pl.Calculate2(a,b,m,1)

pl.IntensitySliceX2(0,f0,f1,f01)
pl.PhaseSliceX2(0,f0,f1,f01)

# %%
# Re[a10]/a00 = delta s/wo , w0 = 1e-3

a10 = .08*1j
a00 = 1

m0 = pl.Modes((0,0,a00))
m1 = pl.Modes((1,0,a10))
m = pl.Modes((1,0,1))
m01 = pl.Modes((0,0,a00),(1,0,a10))

f0 =pl.Calculate(a,b,m0,1)
f1 =pl.Calculate(a,b,m1,1)
f01 = pl.Calculate(a,b,m01,1)
fa = pl.Calculate(a,b,m,1)

pl.IntensitySliceX(0,f0,f1,f01)
pl.PhaseSliceX(0,f0,f1,f01)

# %% [markdown]
# # 2,0

# %%
# Re[a20]/a00 * w0 = (delta w)

a20 = .3
a00 = 1

m0 = pl.Modes((0,0,a00))
m2 = pl.Modes((2,0,a20))
m02 = pl.Modes((0,0,a00),(2,0,a20))

f0 =pl.Calculate(a,b,m0,0)
f2 =pl.Calculate(a,b,m2,0)
f02 = pl.Calculate(a,b,m02,0)

pl.IntensitySliceX(0,f0,f2,f02)

# %%
print pl.pi**(-1/2)
print 1/pl.pi

print pl.pi**-(1/2)

print pl.pi**-(.5)

print 1/(pl.sqrt(pl.pi))

# %%
2/pl.pi

# %%
print (2.0 / 3.14) ** (1.0 / 4.0)
