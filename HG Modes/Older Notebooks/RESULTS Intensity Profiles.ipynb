# %%
import PauLisa as pl, numpy as np, matplotlib.pyplot as plt

# %%
a = pl.defaultParams
b = pl.defaultPlane
c = pl.Plane(-3e-3,3e-3,1000,-3e-3,3e-3,1000)
d=pl.Plane(-1e-3,1e-3,40001,-1e-3,1e-3,3)

# %%
# Re[a10]/a00 = delta s/wo , w0 = 1e-3
fig, axes = plt.subplots(nrows=4, ncols=4, figsize=(22, 18))


m00 = pl.modes((0,0,1))
m01 = pl.modes((0,1,1))
m02 = pl.modes((0,2,1))
m03 = pl.modes((0,3,1))

m10 = pl.modes((1,0,1))
m11 = pl.modes((1,1,1))
m12 = pl.modes((1,2,1))
m13 = pl.modes((1,3,1))

m20 = pl.modes((2,0,1))
m21 = pl.modes((2,1,1))
m22 = pl.modes((2,2,1))
m23 = pl.modes((2,3,1))

m30 = pl.modes((3,0,1))
m31 = pl.modes((3,1,1))
m32 = pl.modes((3,2,1))
m33 = pl.modes((3,3,1))





f00 =pl.calculate(a,c,m00,0)
f01 =pl.calculate(a,c,m01,0)
f02 =pl.calculate(a,c,m02,0)
f03 =pl.calculate(a,c,m03,0)

f10 =pl.calculate(a,c,m10,0)
f11 =pl.calculate(a,c,m11,0)
f12 =pl.calculate(a,c,m12,0)
f13 =pl.calculate(a,c,m13,0)

f20 =pl.calculate(a,c,m20,0)
f21 =pl.calculate(a,c,m21,0)
f22 =pl.calculate(a,c,m22,0)
f23 =pl.calculate(a,c,m23,0)

f30 =pl.calculate(a,c,m30,0)
f31 =pl.calculate(a,c,m31,0)
f32 =pl.calculate(a,c,m32,0)
f33 =pl.calculate(a,c,m33,0)

axes[0][0].contourf(f00.plane.getX(), f00.plane.getY(), abs(f00.getAmp() ** 2))
axes[0][1].contourf(f01.plane.getX(), f01.plane.getY(), abs(f01.getAmp() ** 2))
axes[0][2].contourf(f02.plane.getX(), f02.plane.getY(), abs(f02.getAmp() ** 2))
axes[0][3].contourf(f03.plane.getX(), f03.plane.getY(), abs(f03.getAmp() ** 2))

axes[1][0].contourf(f10.plane.getX(), f10.plane.getY(), abs(f10.getAmp() ** 2))
axes[1][1].contourf(f11.plane.getX(), f11.plane.getY(), abs(f11.getAmp() ** 2))
axes[1][2].contourf(f12.plane.getX(), f12.plane.getY(), abs(f12.getAmp() ** 2))
axes[1][3].contourf(f13.plane.getX(), f13.plane.getY(), abs(f13.getAmp() ** 2))

axes[2][0].contourf(f20.plane.getX(), f10.plane.getY(), abs(f20.getAmp() ** 2))
axes[2][1].contourf(f21.plane.getX(), f21.plane.getY(), abs(f21.getAmp() ** 2))
axes[2][2].contourf(f22.plane.getX(), f22.plane.getY(), abs(f22.getAmp() ** 2))
axes[2][3].contourf(f23.plane.getX(), f23.plane.getY(), abs(f23.getAmp() ** 2))

axes[3][0].contourf(f30.plane.getX(), f30.plane.getY(), abs(f30.getAmp() ** 2))
axes[3][1].contourf(f31.plane.getX(), f31.plane.getY(), abs(f31.getAmp() ** 2))
axes[3][2].contourf(f32.plane.getX(), f32.plane.getY(), abs(f32.getAmp() ** 2))
axes[3][3].contourf(f33.plane.getX(), f33.plane.getY(), abs(f33.getAmp() ** 2))

fig.savefig('intensity-plots.pdf')
fig.tight_layout()
