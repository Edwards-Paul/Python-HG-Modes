# %% [markdown]
# import PauLisa as pl, numpy as np
# a = pl.defaultParams
# b = pl.defaultPlane
#
# print (a)

# %% [markdown]
# ## calculate_q (q parameter equation)

# %%
# spot centers for initial beam and translated beam
# Re[a10]/a00 = delta s/wo , w0 = 1e-3

a10 = .04
a00 = 1

c = pl.Plane(0,1e-4,1000,-1e-3,1e-3,3)

m0 = pl.modes((0,0,a00))
m1 = pl.modes((1,0,a10))
m01 = pl.modes((0,0,a00),(1,0,a10))

f0 =pl.calculate_q(a,c,m0,0)

f1 =pl.calculate_q(a,c,m1,0)
f01 = pl.calculate_q(a,c,m01,0)
f = pl.calculate_q(a,c,m01,0)


pl.intslicex_q(0,f0,f1,f01,labels=['0,0','1,0','Combined'])

print ("predicted x shift: "+str(pl.np.real(a10)/(a00)*a.w0) + " m")
print ("actual: " + str(pl.PeakInt(f01).x[0]-pl.PeakInt(f0).x[0]) + " m")

print ("% err: " + str(((pl.np.real(a10)/1*a.w0)-(pl.PeakInt(f01).x[0]-pl.PeakInt(f0).x[0]))*100/(pl.np.real(a10)/1*a.w0)))

print("Combined intensity 0,0 & 1,0 mode, x=y=z=0: " + str(abs(pl.amplitude_q(a,0,0,0,m01))**2))
print("Predicted combined intensity, x=y=z=0: " + str(abs(np.sqrt(2/pl.pi)/a.w0)**2))
# Out:
# predicted x shift: 4e-05 m
# actual: 3.9800000000000005e-05 m
# % err: 0.49999999999999517
# Combined intensity 0,0 & 1,0 mode, x=y=z=0: 636619.7723675813
# Predicted combined intensity, x=y=z=0: 636619.7723675814

# %%
# Re[a10]/a00 = delta s/wo , w0 = 1e-3

a10 = .04
a00 = 1

test = pl.Params(1e-9,1e-3,0)


m0 = pl.modes((0,0,a00))
m1 = pl.modes((1,0,a10))
m01 = pl.modes((0,0,a00*np.exp()))

f0 =pl.calculate_q(a,b,m0,0)

f1 =pl.calculate_q(a,b,m1,0)
f01 = pl.calculate_q(test,b,m01,0)
f = pl.calculate_q(a,b,m01,0)


pl.intslicex_q(0,f0,f1,f01,labels=['0,0','1,0','Combined'])

print ("predicted x shift: "+str(pl.np.real(a10)/1*a.w0) + " m")
print ("actual: " + str(pl.PeakInt(f01).x[0]-pl.PeakInt(f0).x[0]) + " m")

print ("% err: " + str(((pl.np.real(a10)/1*a.w0)-(pl.PeakInt(f01).x[0]-pl.PeakInt(f0).x[0]))*100/(pl.np.real(a10)/1*a.w0)))

print("Combined intensity 0,0 & 1,0 mode, x=y=z=0: " + str(abs(pl.amplitude_q(a,0,0,0,m01))**2))
print("Predicted combined intensity, x=y=z=0: " + str(abs(np.sqrt(2/pl.pi)/a.w0)**2))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-3-6e37f34488b2> in <module>
#       9 m0 = pl.modes((0,0,a00))
#      10 m1 = pl.modes((1,0,a10))
# ---> 11 m01 = pl.modes((0,0,a00*np.exp()))
#      12
#      13 f0 =pl.calculate_q(a,b,m0,0)
#
# ValueError: invalid number of arguments

# %%
# Re[a10]/a00 = delta s/wo , w0 = 1e-3

a10 = .08
a00 = 1

m0 = pl.modes((0,0,a00))
m1 = pl.modes((1,0,a10))
m01 = pl.modes((0,0,a00),(1,0,a10))

f0 =pl.calculate_q(a,b,m0,0)
f1 =pl.calculate_q(a,b,m1,0)
f01 = pl.calculate_q(a,b,m01,0)

pl.intslicex_q(0,f0,f1,f01,labels=['0,0','1,0','Combined'])

print ("predicted x shift: "+str(pl.np.real(a10)/1*a.w0))
print ("actual: " + str(pl.PeakInt(f01).x[0]-pl.PeakInt(f0).x[0]))
print ("% err: " + str(((pl.np.real(a10)/1*a.w0)-(pl.PeakInt(f01).x[0]-pl.PeakInt(f0).x[0]))*100/(pl.np.real(a10)/1*a.w0)))
# Out:
# predicted x shift: 8e-05
# actual: 7.899802504937365e-05
# % err: 1.2524686882829514

# %% [markdown]
# ## calculate (function without q param.)

# %%
# spot centers for initial beam and translated beam
# Re[a10]/a00 = delta s/wo , w0 = 1e-3

a10 = .04
a00 = 1

m0 = pl.modes((0,0,a00))
m1 = pl.modes((1,0,a10))
m01 = pl.modes((0,0,a00),(1,0,a10))

f0 =pl.calculate(a,b,m0,0)
f1 =pl.calculate(a,b,m1,0)
f01 = pl.calculate(a,b,m01,0)

pl.intslicex(0,f0,f1,f01,labels=['0,0','1,0','Combined'])

print ("predicted x shift: "+str(pl.np.real(a10)/1*a.w0))
print ("actual: " + str(pl.PeakInt(f01).x[0]-pl.PeakInt(f0).x[0]))

print ("% err: " + str(((pl.np.real(a10)/1*a.w0)-(pl.PeakInt(f01).x[0]-pl.PeakInt(f0).x[0]))*100/(pl.np.real(a10)/1*a.w0)))
# Out:
# predicted x shift: 4e-05
# actual: 3.984900377490552e-05
# % err: 0.3774905627362017

# %%
# Re[a10]/a00 = delta s/wo , w0 = 1e-3

a10 = .08
a00 = 1

m0 = pl.modes((0,0,a00))
m1 = pl.modes((1,0,a10))
m01 = pl.modes((0,0,a00),(1,0,a10))

f0 =pl.calculate(a,b,m0,0)
f1 =pl.calculate(a,b,m1,0)
f01 = pl.calculate(a,b,m01,0)

pl.intslicex(0,f0,f1,f01,labels=['0,0','1,0','Combined'])

print ("predicted x shift: "+str(pl.np.real(a10)/a00*a.w0))
print ("actual: " + str(pl.PeakInt(f01).x[0]-pl.PeakInt(f0).x[0]))

print ("% err: " + str(((pl.np.real(a10)/1*a.w0)-(pl.PeakInt(f01).x[0]-pl.PeakInt(f0).x[0]))*100/(pl.np.real(a10)/1*a.w0)))
# Out:
# predicted x shift: 8e-05
# actual: 7.899802504937365e-05
# % err: 1.2524686882829514

# %%
# Re[a10]/a00 = delta s/wo , w0 = 1e-3

a10 = .16
a00 = 1

m0 = pl.modes((0,0,a00))
m1 = pl.modes((1,0,a10))
m01 = pl.modes((0,0,a00),(1,0,a10))

f0 =pl.calculate(a,b,m0,0)
f1 =pl.calculate(a,b,m1,0)
f01 = pl.calculate(a,b,m01,0)

pl.intslicex(0,f0,f1,f01,labels=['0,0','1,0','Combined'])

print ("predicted x shift: "+str(pl.np.real(a10)/a00*a.w0))
print ("actual: " + str(pl.PeakInt(f01).x[0]-pl.PeakInt(f0).x[0]))

print ("% err: " + str(((pl.np.real(a10)/1*a.w0)-(pl.PeakInt(f01).x[0]-pl.PeakInt(f0).x[0]))*100/(pl.np.real(a10)/1*a.w0)))
# Out:
# predicted x shift: 0.00016
# actual: 0.00015254618634534143
# % err: 4.658633534161612

# %% [markdown]
# ## ADD HG 1,0 mode in phase at z = Zr

# %%
# spot centers for initial beam and translated beam
# Re[a10]/a00 = delta s/wo , w0 = 1e-3

a10 = .04
a00 = 1



m0 = pl.modes((0,0,a00))
m1 = pl.modes((1,0,a10))
m01 = pl.modes((0,0,a00),(1,0,a10))

f0 =pl.calculate_q(a,b,m0,a.Zr)
f1 =pl.calculate_q(a,b,m1,a.Zr)
f01 = pl.calculate_q(a,b,m01,a.Zr)
f = pl.calculate_q(a,b,m01,a.Zr)


pl.intslicex_q(0,f0,f1,f01,labels=['0,0','1,0','Combined'])

print ("predicted x shift: "+str(pl.np.real(a10)/1*a.w0))
print ("actual: " + str(pl.PeakInt(f01).x[0]-pl.PeakInt(f0).x[0]))

print ("% err: " + str(((pl.np.real(a10)/1*a.w0)-(pl.PeakInt(f01).x[0]-pl.PeakInt(f0).x[0]))*100/(pl.np.real(a10)/1*a.w0)))


phase_adv= pl.phase(a,0,0,a.Zr,m01)-pl.phase(a,0,0,0,m01)
#predicted atan(Zr/z)=atan(1)
print ("\nPhase advance:" +str(phase_adv) + "\nPredicted:" +str(pl.atan(1)))
# Out:
# predicted x shift: 4e-05
# actual: 3.99990000249993e-05
# % err: 0.0024999375017641717
#
# Phase advance:0.7853981633974483
# Predicted:0.7853981633974483

# %% [markdown]
# ## ADD HG 1,0 mode in phase at z >> Zr

# %%
# spot centers for initial beam and translated beam
# Re[a10]/a00 = delta s/wo , w0 = 1e-3

a10 = .04
a00 = 1

s=3

m0 = pl.modes((0,0,a00))
m1 = pl.modes((1,0,a10))
m01 = pl.modes((0,0,a00),(1,0,a10))

f0 =pl.calculate(a,b,m0,s*a.Zr)
f1 =pl.calculate(a,b,m1,s*a.Zr)
f01 = pl.calculate(a,b,m01,s*a.Zr)
f = pl.calculate(a,b,m01,s*a.Zr)


pl.intslicex(0,f0,f1,f01,labels=['0,0','1,0','Combined'])

print ("predicted x shift: "+str(pl.np.real(a10)/1*a.w0))
print ("actual: " + str(pl.PeakInt(f01).x[0]-pl.PeakInt(f0).x[0]))

print ("% err: " + str(((pl.np.real(a10)/1*a.w0)-(pl.PeakInt(f01).x[0]-pl.PeakInt(f0).x[0]))*100/(pl.np.real(a10)/1*a.w0)))

print ("Phase:" +str(pl.phase(a,0,0,s*a.Zr,m01)-pl.phase(a,0,0,0,m01)) + ", Predicted: " + str(pl.atan(s)))
# Out:
# predicted x shift: 4e-05
# actual: 4.0098997525061814e-05
# % err: -0.2474938126545275
# Phase:1.2490457723982544, Predicted: 1.2490457723982544

# %% [markdown]
# # 1mm beam waist, at waist, add HG10 mode in quadrature phase

# %% [markdown]
# ### 0.04i scale

# %%
# Re[a10]/a00 = delta s/wo , w0 = 1e-3

a10 = .04*1j
a00 = 1

m0 = pl.modes((0,0,a00))
m1 = pl.modes((1,0,a10))
m = pl.modes((1,0,1))
m01 = pl.modes((0,0,a00),(1,0,a10))

f0 =pl.calculate(a,c,m0,0)
f1 =pl.calculate(a,c,m1,0)
f01 = pl.calculate(a,c,m01,0)
fa = pl.calculate(a,c,m,0)

pl.intslicex(0,f0,f1,f01,labels=['0,0','1,0','Combined'])
pl.phaseslicex(0,f0,f1,f01, labels=['0,0','1,0','Combined'])

theta=a.wavelength/pl.pi/a.w0

pred_theta = theta*abs(a10)



phase_comb=(f01.phase[1,:])
phase_diff=(phase_comb[-1]-phase_comb[0])
phase_ang = phase_diff/(c.getX()[-1]-c.getX()[0])
act_theta = phase_ang/2/np.pi*a.wavelength



print ("\n\nWavefront angle: " + str(act_theta) + " rad" + 
      "\nPredicted angle: " + str(pred_theta) + " rad")
# Out:
# Wavefront angle: 1.3518478390373658e-05 rad
# Predicted angle: 1.3547268755982132e-05 rad

# %% [markdown]
# ### 0.08i scale

# %%
# Re[a10]/a00 = delta s/wo , w0 = 1e-3

a10 = .08*1j
a00 = 1

m0 = pl.modes((0,0,a00))
m1 = pl.modes((1,0,a10))
m = pl.modes((1,0,1))
m01 = pl.modes((0,0,a00),(1,0,a10))

f0 =pl.calculate(a,c,m0,0)
f1 =pl.calculate(a,c,m1,0)
f01 = pl.calculate(a,c,m01,0)
fa = pl.calculate(a,c,m,0)

pl.intslicex(0,f0,f1,f01,labels=['0,0','1,0','Combined'])
pl.phaseslicex(0,f0,f1,f01, labels=['0,0','1,0','Combined'])

theta=a.wavelength/pl.pi/a.w0

pred_theta = theta*abs(a10)

phase_adv= pl.phase(a,0,0,a.Zr,m01)-pl.phase(a,0,0,0,m01)

phase_comb=(f01.phase[1,:])
phase_diff=(phase_comb[-1]-phase_comb[0])
phase_ang = phase_diff/(c.getX()[-1]-c.getX()[0])
act_theta = phase_ang/2/np.pi*a.wavelength

#predicted atan(Zr/z)=atan(1)
print ("Phase advance:" +str(phase_adv) + "\nPredicted:" +str(pl.atan(1)))

print ("\n\nWavefront angle: " + str(act_theta) + " rad" + 
      "\nPredicted angle: " + str(pred_theta) + " rad")
# Out:
# Phase advance:0.7853981633974483
# Predicted:0.7853981633974483
#
#
# Wavefront angle: 2.6866818454874857e-05 rad
# Predicted angle: 2.7094537511964265e-05 rad

# %% [markdown]
# # 1mm beam waist, 1m from waist, add HG10 mode in quadrature phase

# %%
# Re[a10]/a00 = delta s/wo , w0 = 1e-3

a10 = .04*1j
a00 = 1

m0 = pl.modes((0,0,a00))
m1 = pl.modes((1,0,a10))
m = pl.modes((1,0,1))
m01 = pl.modes((0,0,a00),(1,0,a10))

f0 =pl.calculate(a,c,m0,1)
f1 =pl.calculate(a,c,m1,1)
f01 = pl.calculate(a,c,m01,1)
fa = pl.calculate(a,c,m,1)

pl.intslicex(0,f0,f1,f01,labels=['0,0','1,0','Combined'])
pl.phaseslicex(0,f0,f1,f01, labels=['0,0','1,0','Combined'])



pred_theta = theta*abs(a10)
shift = pl.PeakInt(f01).x[0]-pl.PeakInt(f0).x[0]
print ("X shift: " + str(shift*1e3) + " mm")
print ("Predicted: " + str(-pred_theta*1e3) + " mm")
# Out:
# X shift: -0.013598640135986401 mm
# Predicted: -0.013547268755982132 mm

# %%
# Re[a10]/a00 = delta s/wo , w0 = 1e-3

a10 = .08*1j
a00 = 1

m0 = pl.modes((0,0,a00))
m1 = pl.modes((1,0,a10))
m = pl.modes((1,0,1))
m01 = pl.modes((0,0,a00),(1,0,a10))

f0 =pl.calculate(a,c,m0,1)
f1 =pl.calculate(a,c,m1,1)
f01 = pl.calculate(a,c,m01,1)
fa = pl.calculate(a,c,m,1)

pl.intslicex(0,f0,f1,f01,labels=['0,0','1,0','Combined'])
pl.phaseslicex(0,f0,f1,f01, labels=['0,0','1,0','Combined'])


pred_theta = theta*abs(a10)
shift = pl.PeakInt(f01).x[0]-pl.PeakInt(f0).x[0]
print ("X shift: " + str(shift*1e3) + " mm")
print ("Predicted: " + str(-pred_theta*1e3)+ " mm")
# Out:
# X shift: -0.02739726027397259 mm
# Predicted: -0.027094537511964265 mm

# %% [markdown]
# 1mm beam waist, 1m from waist, add HG10 mode in phase

# %%
# Re[a10]/a00 = delta s/wo , w0 = 1e-3


a10 = .04
a00 = 1

m0 = pl.modes((0,0,a00))
m1 = pl.modes((1,0,a10))
m = pl.modes((1,0,1))
m01 = pl.modes((0,0,a00),(1,0,a10))

f0 =pl.calculate(a,c,m0,a.Zr)
f1 =pl.calculate(a,c,m1,a.Zr)
f01 = pl.calculate(a,c,m01,a.Zr)
fa = pl.calculate(a,c,m,a.Zr)

pl.intslicex(0,f0,f01,labels=['0,0','Combined'])
pl.phaseslicex(0,f0,f01, labels=['0,0','Combined'] )



pred_theta = theta*abs(a10)
shift = pl.PeakInt(f01).x[0]-pl.PeakInt(f0).x[0]

print ("predicted x shift: "+ str(pl.np.real(a10)/1*a.w0))
print ("actual: " + str(pl.PeakInt(f01).x[0]-pl.PeakInt(f0).x[0]))
print ("% err: " + str(((pl.np.real(a10)/1*a.w0)-(pl.PeakInt(f01).x[0]-pl.PeakInt(f0).x[0]))*100/(pl.np.real(a10)/1*a.w0)))


print  ("HG 0,0 Gouy Phase term : " + str(np.angle((pl.e ** ((1j) * (0 + 1) * pl.gouy_phase(a.Zr, 1, a))))))

print  ("HG 0,1 Gouy Phase term (scaled): " + str(a10*np.angle((pl.e ** ((1j) * (1 + 1) * pl.gouy_phase(a.Zr, 2, a))))))
# Out:
# predicted x shift: 4e-05
# actual: 3.9996000399960055e-05
# % err: 0.009999000099870778
# HG 0,0 Gouy Phase term : 0.7853981633974483
# HG 0,1 Gouy Phase term (scaled): 0.06283185307179587

# %% [markdown]
# ## Higher resolution in X of the previous:

# %%
# Re[a10]/a00 = delta s/wo , w0 = 1e-3
d = pl.Plane(3e-5,5e-5,1001,-1e-3,1e-3,3)

a10 = .04
a00 = 1

m0 = pl.modes((0,0,a00))
m1 = pl.modes((1,0,a10))
m = pl.modes((1,0,1))
m01 = pl.modes((0,0,a00),(1,0,a10))

f0 =pl.calculate(a,d,m0,a.Zr)
f1 =pl.calculate(a,d,m1,a.Zr)
f01 = pl.calculate(a,d,m01,a.Zr)
fa = pl.calculate(a,d,m,a.Zr)

pl.phaseslicex(0,f0,f01, labels=['0,0','Combined'], ylim=[3e6,3.5e6])




print  ("HG 0,0 Gouy Phase term : " + str(np.angle((pl.e ** ((1j) * (0 + 1) * pl.gouy_phase(a.Zr, 1, a))))))

print  ("HG 0,1 Gouy Phase term (scaled): " + str(a10*np.angle((pl.e ** ((1j) * (1 + 1) * pl.gouy_phase(a.Zr, 2, a))))))
# Out:
# HG 0,0 Gouy Phase term : 0.7853981633974483
# HG 0,1 Gouy Phase term (scaled): 0.06283185307179587

# %%
print (d.getX().shape)
print (d.getX()[501]-(d.getX()[500]))
delta_x=(d.getX()[501]-(d.getX()[500]))
# Out:
# (1001,)
# 1.999999999999642e-08

# %%
print (f01.phase.shape)
print (f01.phase[1][501]-f01.phase[1][500])
p01 = f01.phase[1][501]
delta_p01=(f01.phase[1][501]-f01.phase[1][500])
print (f0.phase.shape)
print (f0.phase[1][501]-f01.phase[1][500])
delta_p0=(f0.phase[1][501]-f0.phase[1][500])
p0 = f0.phase[1][501]
print (p01,p0)
print(p01-p0)
print(delta_p01-delta_p0)
# Out:
# (3, 1001)
# -2.756541994664019e-09
# (3, 1001)
# -0.0015982429306583557
# 0.7861956033715647 0.7845973631974483
# 0.001598240174116361
# 7.974434580448886e-07

# %%
print (p01-p0/delta_x)
print (p01-p0/4e-5)

wavelength = 2*pl.pi*p01
print(wavelength)
print(delta_x/wavelength)
# Out:
# -39229867.37368383
# -19614.147884332837
# 4.939812663673405
# 4.0487365334870356e-09
