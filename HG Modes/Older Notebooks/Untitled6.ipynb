# %%
import PauLisa as pl, PL_Plot as plplt,plback as plb, Tophat_integration_AW as th, numpy as np, matplotlib.pyplot as plt, cmath as cm
from Signals import *

from numpy import pi as pi
from numpy import angle
from math import e
from numpy import sqrt as sqrt
from scipy.special import erf as erf
import mpmath as mp
import scipy.io

from math import pi, log, exp, sin, cos, atan, e, radians, degrees
from scipy.special import gamma as gamma
from scipy.special import erf as erf
from math import factorial as fact
import cmath
from cmath import sqrt as sqrt
import numpy as np

from time import process_time

inf=np.inf

import pandas as pd
from pprint import pprint

# %%
#meng angle, lps, contrast, dws


lam = 1064e-9
k = 2*pi/lam
a = ([0,10e-6,20e-6,50e-6,100e-6])

mat = scipy.io.loadmat('Gauss_Gauss_Data_6_11')
mat2 = scipy.io.loadmat('paul_HG00.mat')

print(mat2['total_lps_slope_HG00'].shape)

for x in mat:
  print(x)
angle=mat2['angle'].ravel()

print(mat['description'])
# Out:
# (5, 101)
# __header__
# __version__
# __globals__
# DWSRG
# LPSRG
# LPSTG
# anrn
# description
# offs
# tst4G1
# tst4G2
# tst4G3
# tst4G4
# ['Here is the data from Gaussian-Gaussian Overlaps.\nThere are 5 lateral offsets (0,10,20,50, and 100 micrometers\nfound in the variable "offs". In these the modes were matched\nbecause it had seemed that had better matched Mengyuans data.\nThe four quadrants complex amplitude data is stored in the variables\n"tst4G1","tst4G2","tst4G3", and "tst4G4" (last number corresponding to\nquadrant number, 1 is +x+y, 2 -x+y, 3 -x-y, and 4 +x-y). These\ndata sets are 4d arrays, 101x5x3x2, where element (m,n,p,q) corresponds\nto angle m for offset n in data type p where p = 1 corresponds to\nwhen local oscillator and measurement beams are gaussian with waist\n1mm, p = 2 is the data set where both waists are 1/3 mm, and p = 3\ncorresponds to the case when they are not mode matched, and should\nthe same as modeling the tophat to 0th order i.e. a gaussian with\nwaist 1/3mm as the RX and 1mm waist as the LO. q = 1 corresponds to\nrotations about the RX waist, q = 2 the rotations about the LO waist.\nIn both as before we are rotating the RX beam and again as before\nwe had the waists are 10mm before the PD, which is 4cmx4cm\nor in your case 4cm in diameter (2 in radius), with gaps 20 micron\nwide. These are rotated about the RX gaussian waist. LPSTG,\nLPSRG, and DWSRG are the variables holding the finalized total\nLPS in LPSTG (that which Mengyuan was using), the regular LPS in\nLPSRG (average of quadrant phases, what Paul had been using), and \nthe regular DWS signal in DWSRG. \'anrn\' are the angles.']

# %%
for i in range(len(lps_th)):
    plt.plot(angle,lps_th[i])
    
plt.xlabel(r'Tilt Angle, $\alpha\;$[' + 'rad]', fontsize=15) 
plt.ticklabel_format(axis="y", style="sci", scilimits=(0,0))
plt.ylabel(r'Slope $[' +  'mm/rad]$', fontsize=15) 
plt.title(r' LPS') 
# plt.xlim([-200e-6,200e-6])


plt.plot()
plt.grid()
# Out:
# No handles with labels found to put in legend.

# %%
for i in range(len(total_lps_th)):
    plt.plot(angle,total_lps_th[i])
    
    
plt.xlabel(r'Tilt Angle, $\alpha\;$[' + 'rad]', fontsize=15) 
plt.ticklabel_format(axis="y", style="sci", scilimits=(0,0))
plt.ylabel(r'Slope $[' +  'mm/rad]$', fontsize=15) 
plt.title(r'Total LPS Slope') 
# plt.xlim([-200e-6,200e-6])
plt.legend()
plt.plot()

plt.grid()
# Out:
# No handles with labels found to put in legend.
