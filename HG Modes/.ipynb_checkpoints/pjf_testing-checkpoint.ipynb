# %%
import PauLisa
import matplotlib.pyplot as plt
import numpy as np

# %%
PauLisa.Modes((0,0,1),(1,0,0))

# %%
PauLisa.ShowModes()
# Out:
# n\m [0]
# 0   [1]
# 1   [0]

# %%
PauLisa.Calculate(-0.01,0.01,-0.01,0.01,0)

# %%
np.shape(PauLisa.x)
#plt.figure
plt.plot(PauLisa.x,PauLisa.f)
plt.grid()
