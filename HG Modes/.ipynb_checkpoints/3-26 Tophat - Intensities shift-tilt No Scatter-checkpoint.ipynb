# %% [markdown]
# # Shifted-tilted Tophat at Gaussian interference at waist
#
# Tophat incoming with shift then tilt ( to 1st-order in both):
# \begin{align*}
# \sum u_{nm} \rightarrow_{shift,tilt} &
#     \sum u_{nm}' \left[
#         (1 + \frac{2 a x}{w_0^2})(1+ i k \alpha x)
#     \right]
#     \\
#     =&
#     \sum u_{nm}'
#     \left[
#         (1 + \frac{2 a }{w_0^2} x + i k \alpha x + i \frac{2 k \alpha a}{w_0^2} x^2 )
#     \right]
# \end{align*}
#
# where the second term arises from exponential terms in HG modes, $u_{nm}'$ a function of $H_n(\frac{\sqrt{2}(x-a)}{w(z)})$
#
# For $x$:
#
# \begin{equation}
# x u_{n,m} = \frac{w_0}{2}
# \Big[
# 	(1 - i \frac{z}{z_R})
# 	\sqrt{n+1} u_{n+1,m}
# 	+
# 	\sqrt{n}
# 	(1+i \frac{z}{z_R})
# 	u_{n-1,m}
# \Big]
# \end{equation}
#
# For $x^2$:
#
# \begin{equation}
# x^2 u_{n,m} = \frac{w_0^2}{4}
# \Big[
# 	(1 - i \frac{z}{z_R})^2
# 	\sqrt{(n+1)(n+2)} u_{n+2,m}
# 	+
# 	(2n+1)
# 	(1+ (\frac{z}{z_R})^2)
# 	u_{n,m}
# 	+
# 	\sqrt{n(n-1)}
# 	(1+i \frac{z}{z_R} )^2
# 	u_{n-2,m}
# \Big]
# \end{equation}

# %%
import PauLisa as pl, numpy as np, matplotlib.pyplot as plt
from scipy.special import erfi as erfi
pi=np.pi

import scipy.io

# %%
mat = scipy.io.loadmat('Top_hat_for_paul.mat')
for x in mat:
  print(x)
# Out:
# __header__
# __version__
# __globals__
# coeftop
# read_me_paul
# wb

# %%
print(mat['read_me_paul'])
print(mat['wb'])

coef=mat['coeftop'].ravel()
# Out:
# ['wb is the waist to use for tophat basis with tophat radius 1mm,coeftop are the mode coefficients.']
# [[0.00023067]]

# %% [markdown]
# Using simtools mode indexing in Python:
#
# $
# m = \frac{(N+1)(N+2)}{2}- (A_{python} + 1)
# $
#
# $
# \rightarrow A_{python} =  \frac{(N+1)(N+2)}{2} + 1 -m
# $
#
# $
# n = A_{python} - \frac{N(N+1)}{2} = N-m
# $
#
# $
# \rightarrow A_{python} = N-m + - \frac{N(N+1)}{2}
# $
#
# $
# N = floor( \frac{\sqrt{8A_{python}+1} - 1}{2} ) = ceil(\frac{\sqrt{9+8A_{python}} - 3}{2} )
# $

# %% [raw]
#   (FROM UNIT POWER)
#
#   Tophat 10x10 entries
#
#     0         2         4         6...
#     0.5646    0.3896    0.2935    0.1570   -0.0031   -0.0719   -0.0055    0.0445   -0.0103   -0.0263
#     0.3896    0.2396    0.1216   -0.0024   -0.0536   -0.0041    0.0326   -0.0075   -0.0191    0.0171
#     0.2935    0.1216   -0.0022   -0.0496   -0.0037    0.0295   -0.0068   -0.0171    0.0152    0.0019
#     0.1570   -0.0024   -0.0496   -0.0036    0.0284   -0.0064   -0.0162    0.0143    0.0018   -0.0124
#    -0.0031   -0.0536   -0.0037    0.0284   -0.0063   -0.0158    0.0139    0.0017   -0.0120    0.0094
#    -0.0719   -0.0041    0.0295   -0.0064   -0.0158    0.0138    0.0017   -0.0117    0.0092    0.0004
#    -0.0055    0.0326   -0.0068   -0.0162    0.0139    0.0017   -0.0117    0.0091    0.0004   -0.0078
#     0.0445   -0.0075   -0.0171    0.0143    0.0017   -0.0117    0.0091    0.0004   -0.0077    0.0080
#    -0.0103   -0.0191    0.0152    0.0018   -0.0120    0.0092    0.0004   -0.0077    0.0080   -0.0027
#    -0.0263    0.0171    0.0019   -0.0124    0.0094    0.0004   -0.0078    0.0080   -0.0027   -0.0034
#
#
# Note that these give coefficients (for unit power, not unit intensity tophat, for that multiply by sqrt(pi)*r) for modes (2m,2n) so for example row 1 column 4 gives coefficient of mode (0,6) (first non-zero indices have a 0, so column or row 1 correspond to zero, column or row 2 correspond to 2, 3 to 4, 4 to 6, 5 to 8 and so forth). This means here are non-zero indices from HG00 to HG(18,18).
#
# Again, this is for a normal power tophat, not normal intensity (which would have a power equal to the surface area of the pupil).

# %%
def N_f(A):
    
    res = np.floor((np.sqrt(8*A+1)-1)/2)
    
    #res = (np.sqrt(9+8*A)-3)/2
    return(res)

def m(N,A):
    res = (N+1)*(N+2)/2 - (A+1)
    return(res)

#def n(N,A):
#    m= (N+1)*(N+2)/2 - (A+1)
#    res = N-m
#    return(res)
def n(N,A):
    res = A - (N*(N+1)/2)
    return(res)

NumberModes = int(len(coef))
listModesN = [None] * NumberModes
listModesM = [None] * NumberModes
listModesC = [None] * NumberModes



#for i in range(len(coef)):
#    A=i
#    N= N_f(A)
#
#    if (m(N,A)%2 == 0) & (n(N,A)%2 == 0):
#        print(coef[A], '\t\t\t' , m(N,A), ',' , n(N,A))

for i in range(NumberModes):
    A=i
    N= N_f(A)
    listModesN[i] = int(m(N,A))
    listModesM[i] = int(n(N,A))
    listModesC[i] = coef[i]

# %%
plane = pl.Plane(-2e-3, 2e-3, 300, -2e-3, 2e-3, 300)
params = pl.Params(1064e-9, 0.00023067,0)

modes = pl.create_modes(listModesM,listModesN,listModesC,NumberModes)

print(params)
print(plane)
# Out:
# wavelength=1.064e-06
# w0=0.00023067
# z0=0
# Zr=0.15710516963503632
# q0=0.15710516963503632j
#
# xmin=-0.002,xmax=0.002,xpoints=300,x step size = 1.3333333333333333e-05
# ymin=-0.002,ymax=0.002,ypoints=300,y step size = 1.3333333333333333e-05

# %%
f = pl.calculate(params,plane,modes,0)

# %%
pl.intslicex(0,f)
pl.intslicey(0,f)

# %%
pl.show_modes(modes)

# %%
a = 100e-6
alpha = 0

# %%
m0 = pl.scatter_case2(0,params,a,alpha,modes)

# %%
f0 = pl.calculate_case2(params,plane,m0,0,a,alpha)

# %%
pl.intslicex(0,f0, xlim=[-1.5e-3,1.5e-3], labels="tophat")
pl.intslicey(0,f0, xlim=[-1.5e-3,1.5e-3], labels="tophat")

# %%
fig, ax = plt.subplots(figsize=(13, 10))
cs = plt.contourf(f0.plane.getX(), f0.plane.getY(), abs(f0.getAmp() ** 2))
plt.xlabel('X [m]')
plt.ylabel('Y [m]')
cbar = fig.colorbar(cs)
plt.title('Intensity')
ax.ticklabel_format(axis='x', style='sci', scilimits=(-3, -3), useMathText=True)
ax.ticklabel_format(axis='y', style='sci', scilimits=(-3, -3), useMathText=True)

# %%
f0b = pl.calculate(params,plane,m0,0)

# %%
pl.intslicex(0,f0b, xlim=[-1.5e-3,1.5e-3], labels="tophat")
pl.intslicey(0,f0b, xlim=[-1.5e-3,1.5e-3], labels="tophat")

# %%
fig, ax = plt.subplots(figsize=(13, 10))
cs = plt.contourf(f0.plane.getX(), f0.plane.getY(), abs(f0.getAmp() ** 2))
plt.xlabel('X [m]')
plt.ylabel('Y [m]')
cbar = fig.colorbar(cs)
plt.title('Intensity')
ax.ticklabel_format(axis='x', style='sci', scilimits=(-3, -3), useMathText=True)
ax.ticklabel_format(axis='y', style='sci', scilimits=(-3, -3), useMathText=True)

# %%
m = pl.scatter_case2(0,params,0,0,modes)

# %%
f = pl.calculate_case2(params,plane,modes_list[100],0,100e-6,500e-6)

# %%
print(f.amp.shape)
print(alpha)
# Out:
# (300, 300)
# [-5.0e-04 -4.9e-04 -4.8e-04 -4.7e-04 -4.6e-04 -4.5e-04 -4.4e-04 -4.3e-04
#  -4.2e-04 -4.1e-04 -4.0e-04 -3.9e-04 -3.8e-04 -3.7e-04 -3.6e-04 -3.5e-04
#  -3.4e-04 -3.3e-04 -3.2e-04 -3.1e-04 -3.0e-04 -2.9e-04 -2.8e-04 -2.7e-04
#  -2.6e-04 -2.5e-04 -2.4e-04 -2.3e-04 -2.2e-04 -2.1e-04 -2.0e-04 -1.9e-04
#  -1.8e-04 -1.7e-04 -1.6e-04 -1.5e-04 -1.4e-04 -1.3e-04 -1.2e-04 -1.1e-04
#  -1.0e-04 -9.0e-05 -8.0e-05 -7.0e-05 -6.0e-05 -5.0e-05 -4.0e-05 -3.0e-05
#  -2.0e-05 -1.0e-05  0.0e+00  1.0e-05  2.0e-05  3.0e-05  4.0e-05  5.0e-05
#   6.0e-05  7.0e-05  8.0e-05  9.0e-05  1.0e-04  1.1e-04  1.2e-04  1.3e-04
#   1.4e-04  1.5e-04  1.6e-04  1.7e-04  1.8e-04  1.9e-04  2.0e-04  2.1e-04
#   2.2e-04  2.3e-04  2.4e-04  2.5e-04  2.6e-04  2.7e-04  2.8e-04  2.9e-04
#   3.0e-04  3.1e-04  3.2e-04  3.3e-04  3.4e-04  3.5e-04  3.6e-04  3.7e-04
#   3.8e-04  3.9e-04  4.0e-04  4.1e-04  4.2e-04  4.3e-04  4.4e-04  4.5e-04
#   4.6e-04  4.7e-04  4.8e-04  4.9e-04  5.0e-04]

# %%
pl.intslicex(0,f, xlim=[-1.5e-3,1.5e-3], labels="alpha")

# %%
print(alpha)
# Out:
# [-5.0e-04 -4.9e-04 -4.8e-04 -4.7e-04 -4.6e-04 -4.5e-04 -4.4e-04 -4.3e-04
#  -4.2e-04 -4.1e-04 -4.0e-04 -3.9e-04 -3.8e-04 -3.7e-04 -3.6e-04 -3.5e-04
#  -3.4e-04 -3.3e-04 -3.2e-04 -3.1e-04 -3.0e-04 -2.9e-04 -2.8e-04 -2.7e-04
#  -2.6e-04 -2.5e-04 -2.4e-04 -2.3e-04 -2.2e-04 -2.1e-04 -2.0e-04 -1.9e-04
#  -1.8e-04 -1.7e-04 -1.6e-04 -1.5e-04 -1.4e-04 -1.3e-04 -1.2e-04 -1.1e-04
#  -1.0e-04 -9.0e-05 -8.0e-05 -7.0e-05 -6.0e-05 -5.0e-05 -4.0e-05 -3.0e-05
#  -2.0e-05 -1.0e-05  0.0e+00  1.0e-05  2.0e-05  3.0e-05  4.0e-05  5.0e-05
#   6.0e-05  7.0e-05  8.0e-05  9.0e-05  1.0e-04  1.1e-04  1.2e-04  1.3e-04
#   1.4e-04  1.5e-04  1.6e-04  1.7e-04  1.8e-04  1.9e-04  2.0e-04  2.1e-04
#   2.2e-04  2.3e-04  2.4e-04  2.5e-04  2.6e-04  2.7e-04  2.8e-04  2.9e-04
#   3.0e-04  3.1e-04  3.2e-04  3.3e-04  3.4e-04  3.5e-04  3.6e-04  3.7e-04
#   3.8e-04  3.9e-04  4.0e-04  4.1e-04  4.2e-04  4.3e-04  4.4e-04  4.5e-04
#   4.6e-04  4.7e-04  4.8e-04  4.9e-04  5.0e-04]

# %%
f = pl.calculate_case2(params,plane,m,0,a,alpha)

# %%
pl.intslicex(0,f, xlim=[-1.5e-3,1.5e-3], labels="alpha")

# %%
pl.show_modes(m)

# %%
pl.show_modes(modes)

# %% [markdown]
# ### Input Parameters

# %%
#spot, wavelength, shift
w= 1e-3
lam= 1064e-9
a = 100e-6  #100 micron shift
k = 2*pi/lam
#z0 = 0.00023067 # for tophat with 1e-3 radius

#alpha(10nrad)
alpha_min=-500e-6
alpha_max=500e-6
num_points = 101
alpha = np.linspace(alpha_min,alpha_max,num = num_points)

## PLOT SCALES AND LABELS
micro = 10**(6)
nano = 10**(9)
cycle = 1/(2*pi)
rad = 1
xlab = 'u'
ylab = 'rad'

##SET SCALES
alpha_scale = micro
phase_scale = rad

if(alpha_scale==nano):
    xlab = 'n'
if(phase_scale==cycle):
    ylab = 'cycles'

# %%
plt.figure()

plt.plot(plane.getX(),(abs(f.amp))**2)

plt.grid()
